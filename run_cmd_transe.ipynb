# %%
import subprocess, sys

cmd = [
    r"D:\anaconda3\envs\py3_11_5_env_00\Scripts\dglke_train.exe",
    "--model_name", "TransE_l1",
    "--data_path", r"D:\workspace\***\小论文-知识图谱\data\OpenBG500",
    "--format", "raw_udd_hrt",
    "--data_files", "OpenBG500_train.tsv", "OpenBG500_dev.tsv", "OpenBG500_answer.tsv",
    "--batch_size", "256",              
    "--neg_sample_size", "10",
    "--hidden_dim", "200",
    "--gamma", "12.0",
    "--lr", "0.1",
    "--max_step", "2000",
    "--log_interval", "100",
    "--eval_interval", "1000",
    "--eval_percent", "100",
    "--test",
    "--gpu", "-1",                       
    "--save_path", r"D:\workspace\对外经济贸易大学同等学力课程资料\小论文-知识图谱\data\OpenBG500\ckpt_transe_l1",
]

p = subprocess.run(cmd, capture_output=True, text=True)
print("RETURNCODE:", p.returncode)
print("STDOUT:\n", p.stdout)
print("STDERR:\n", p.stderr)
